# %% [markdown]
# # 1. Loading Credentials from Kedro
#
# # Configuration
#
# > *Note:* This documentation is based on `Kedro 0.15.8`, if you spot anything that is incorrect then please create an [issue](https://github.com/quantumblacklabs/kedro/issues) or pull request.
# >
# > This section contains detailed information about configuration.
#
# Relevant API documentation: [ConfigLoader](/kedro.config.ConfigLoader)
#
# ## Local and base configuration
#
# We recommend that you keep all configuration files in the `conf` directory of a Kedro project. However, if you prefer, you may point Kedro to any other directory and change the configuration paths by overriding `CONF_ROOT` variable from the derived `ProjectContext` class in `src/<project-package>/run.py` as follows:
# ```python
# class ProjectContext(KedroContext):
#     CONF_ROOT = "new_conf"
#     # ...
# ```
#
# ## Loading
#
# Kedro-specific configuration (e.g., `DataCatalog` configuration for IO) is loaded using the `ConfigLoader` class:
#
# ```python
# from kedro.config import ConfigLoader
#
# conf_paths = ["conf/base", "conf/local"]
# conf_loader = ConfigLoader(conf_paths)
# conf_catalog = conf_loader.get("catalog*", "catalog*/**")
# ```
#
# This will recursively scan for configuration files firstly in `conf/base/` and then in `conf/local/` directory according to the following rules:
#
# * ANY of the following is true:
#   * filename starts with `catalog` OR
#   * file is located in a sub-directory whose name is prefixed with `catalog`
# * AND file extension is one of the following: `yaml`, `yml`, `json`, `ini`, `pickle`, `xml` or `properties`
#
# Configuration information from files stored in `base` or `local` that match these rules is merged at runtime and returned in the form of a config dictionary:
#
# * If any 2 configuration files located inside the same environment path (`conf/base/` or `conf/local/` in this example) contain the same top-level key, `load_config` will raise a `ValueError` indicating that the duplicates are not allowed.
#
# > *Note:* Any top-level keys that start with `_` character are considered hidden (or reserved) and therefore are ignored right after the config load. Those keys will neither trigger a key duplication error mentioned above, nor will they appear in the resulting configuration dictionary. However, you may still use such keys for various purposes. For example, as [YAML anchors and aliases](https://confluence.atlassian.com/bitbucket/yaml-anchors-960154027.html).
#
# * If 2 configuration files have duplicate top-level keys, but are placed into different environment paths (one in `conf/base/`, another in `conf/local/`, for example) then the last loaded path (`conf/local/` in this case) takes precedence and overrides that key value. `ConfigLoader.get(<pattern>, ...)` will not raise any errors, however a `DEBUG` level log message will be emitted with the information on the over-ridden keys.
# * If the same environment path is passed multiple times, a `UserWarning` will be emitted to draw attention to the duplicate loading attempt, and any subsequent loading after the first one will be skipped.

# %%
# Load Credentials
from kedro.config import ConfigLoader

conf_paths = ["conf/base", "conf/local"]
conf_loader = ConfigLoader(conf_paths)
conf_catalog = conf_loader.get("credentials*")

# %% [markdown]
# # 2. The Azure Machine Learning SDK for Python
# While graphical interfaces like Azure Machine Learning studio make it easy to create and manage machine learning assets, it is often dvantageous to use a code-based approach to managing resources. By writing scripts to create and manage resources, you can:
#
# * Automate asset creation and configuration to make it repeatable.
# * Ensure consistency for resources that must be replicated in multiple environments (for example, development, test, and production)
# * Incorporate machine learning asset configuration into developer operations (DevOps) workflows, such as continuous integration / continuous deployment (CI/CD) pipelines.
# Azure Machine Learning provides software development kits (SDKs) for Python and R, which you can use to create, manage, and use assets in an Azure Machine Learning workspace.
#
# > *Note:*: This course focuses on the Python SDK because it has broader capabilities than the R SDK, which is in preview at the time of writing.
#
# # 3.Installing the Azure Machine Learning SDK for Python
# You can install the Azure Machine Learning SDK for Python by using the pip package management utility, as shown in the following code sample:
#
# ```python
# pip install azureml-sdk
# ```
#
# The SDK includes optional extras that aren't required for core operations, but can be useful in some scenarios. For example, the notebooks extra includes widgets for displaying detailed output in Jupyter Notebooks, the automl extra includes packages for automated machine learning training, and the explain extra includes packages for generating model explanations. To install extras, specify them in brackets as shown here:
#
# ```python
# pip install azureml-sdk[notebooks,automl,explain]
# ```
#
# More Information: For more information about installing the Azure Machine Learning SDK for Python, see the SDK documentation. Also, you should be aware that the SDK is updated on a regular basis, and review the release notes for the latest release.

# %%
# !pip install azureml-sdk[notebooks,automl,explain]
# Out:
# Requirement already satisfied: azureml-sdk[automl,explain,notebooks] in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (1.2.0)
# Requirement already satisfied: azureml-train-automl-client~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied: azureml-dataprep[fuse]<1.4.0a,>=1.3.5 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.3.5)
# Requirement already satisfied: azureml-core~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.2.0.post1)
# Requirement already satisfied: azureml-train~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied: azureml-pipeline~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Collecting azureml-train-automl~=1.2.0; extra == "automl"
#   Downloading azureml_train_automl-1.2.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-explain-model~=1.2.0; extra == "explain"
#   Downloading azureml_explain_model-1.2.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: azureml-widgets~=1.2.0; extra == "notebooks" in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied: azureml-contrib-notebook~=1.2.0; extra == "notebooks" in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied: pytz in /home/yuvraj/.local/lib/python3.6/site-packages (from azureml-train-automl-client~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2019.3)
# Requirement already satisfied: azureml-telemetry~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-train-automl-client~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied: azureml-automl-core~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-train-automl-client~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied: azureml-dataprep-native<15.0.0,>=14.1.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (14.1.0)
# Requirement already satisfied: dotnetcore2>=2.1.13 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (2.1.13)
# Requirement already satisfied: azure-identity>=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.1.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied: fusepy>=3.0.1; extra == "fuse" in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (3.0.1)
# Requirement already satisfied: contextlib2 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.6.0.post1)
# Requirement already satisfied: azure-mgmt-resource>=1.2.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (8.0.1)
# Requirement already satisfied: msrestazure>=0.4.33 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.6.3)
# Requirement already satisfied: adal>=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.2.2)
# Requirement already satisfied: azure-graphrbac>=0.40.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.61.1)
# Requirement already satisfied: PyJWT in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.7.1)
# Requirement already satisfied: requests>=2.19.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.23.0)
# Requirement already satisfied: azure-mgmt-keyvault>=0.40.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.2.0)
# Requirement already satisfied: ruamel.yaml<=0.15.89,>=0.15.35 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.15.89)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/yuvraj/.local/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.8.0)
# Requirement already satisfied: jmespath in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.9.5)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.* in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.8)
# Requirement already satisfied: ndg-httpsclient in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied: azure-mgmt-storage>=1.5.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (8.0.0)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.8.0)
# Requirement already satisfied: pathspec in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.7.0)
# Requirement already satisfied: SecretStorage in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (3.1.2)
# Requirement already satisfied: pyopenssl in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (19.1.0)
# Requirement already satisfied: docker in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (4.2.0)
# Requirement already satisfied: jsonpickle in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.3)
# Requirement already satisfied: backports.tempfile in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.0)
# Requirement already satisfied: azure-mgmt-authorization>=0.40.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.60.0)
# Requirement already satisfied: msrest>=0.5.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.6.11)
# Requirement already satisfied: azure-common>=1.1.12 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.1.25)
# Requirement already satisfied: urllib3>=1.23 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.25.8)
# Requirement already satisfied: azureml-train-core~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-train~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied: azureml-pipeline-core~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-pipeline~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Requirement already satisfied: azureml-pipeline-steps~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-pipeline~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Collecting azureml-automl-runtime~=1.2.0
#   Downloading azureml_automl_runtime-1.2.0-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 3.0 MB/s
# Collecting azureml-train-automl-runtime~=1.2.0
#   Downloading azureml_train_automl_runtime-1.2.0-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.5 MB/s
# Collecting azureml-interpret~=1.2.0
#   Downloading azureml_interpret-1.2.0-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.6 MB/s
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.5.1)
# Requirement already satisfied: papermill<2 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.2.1)
# Requirement already satisfied: ipykernel in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.2.0)
# Requirement already satisfied: ipython in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.13.0)
# Requirement already satisfied: applicationinsights in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-telemetry~=1.2.0->azureml-train-automl-client~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.11.9)
# Requirement already satisfied: distro>=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from dotnetcore2>=2.1.13->azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (1.4.0)
# Requirement already satisfied: msal<2.0.0,>=1.0.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azure-identity>=1.2.0->azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (1.1.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.0.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azure-identity>=1.2.0->azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied: msal-extensions~=0.1.3 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azure-identity>=1.2.0->azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (0.1.3)
# Requirement already satisfied: six>=1.6 in /home/yuvraj/.local/lib/python3.6/site-packages (from azure-identity>=1.2.0->azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (1.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2019.11.28)
# Requirement already satisfied: idna<3,>=2.5 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from requests>=2.19.1->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (3.0.4)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.14.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ndg-httpsclient->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.4.8)
# Requirement already satisfied: jeepney>=0.4.2 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from SecretStorage->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.4.3)
# Requirement already satisfied: websocket-client>=0.32.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from docker->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.57.0)
# Requirement already satisfied: backports.weakref in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.0.post1)
# Requirement already satisfied: isodate>=0.6.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied: flake8<=3.7.9,>=3.1.0; python_version >= "3.6" in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-train-core~=1.2.0->azureml-train~=1.2.0->azureml-sdk[automl,explain,notebooks]) (3.7.9)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from azureml-train-core~=1.2.0->azureml-train~=1.2.0->azureml-sdk[automl,explain,notebooks]) (1.2.0)
# Collecting scipy<=1.1.0,>=1.0.0
#   Downloading scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 6.2 MB/s
# Collecting pandas<=0.23.4,>=0.21.0
#   Using cached pandas-0.23.4-cp36-cp36m-manylinux1_x86_64.whl (8.9 MB)
# Collecting onnx>=1.5.0
#   Downloading onnx-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 7.2 MB/s
# Collecting pmdarima==1.1.1
#   Downloading pmdarima-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (682 kB)
#      |████████████████████████████████| 682 kB 7.2 MB/s
# Collecting py-cpuinfo
#   Downloading py-cpuinfo-5.0.0.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 428 kB/s
# Requirement already satisfied: statsmodels<=0.10.2,>=0.9.0 in /home/yuvraj/.local/lib/python3.6/site-packages (from azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.10.0)
# Collecting psutil<6.0.0,>=5.2.2
#   Downloading psutil-5.7.0.tar.gz (449 kB)
#      |████████████████████████████████| 449 kB 4.9 MB/s
# Collecting resource>=0.1.8
#   Downloading Resource-0.2.1-py2.py3-none-any.whl (25 kB)
# Collecting wheel==0.30.0
#   Downloading wheel-0.30.0-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 4.3 MB/s
# Requirement already satisfied: patsy>=0.5.1 in /home/yuvraj/.local/lib/python3.6/site-packages (from azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Collecting gensim
#   Downloading gensim-3.8.1-cp36-cp36m-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 4.8 MB/s
# Collecting skl2onnx==1.4.9
#   Downloading skl2onnx-1.4.9-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 8.4 MB/s
# Collecting onnxmltools==1.4.1
#   Downloading onnxmltools-1.4.1-py2.py3-none-any.whl (371 kB)
#      |████████████████████████████████| 371 kB 4.9 MB/s
# Collecting onnxconverter-common<=1.6.0,>=1.4.2
#   Downloading onnxconverter_common-1.6.0-py2.py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.8 MB/s
# Collecting scikit-learn<=0.20.3,>=0.19.0
#   Using cached scikit_learn-0.20.3-cp36-cp36m-manylinux1_x86_64.whl (5.4 MB)
# Collecting numpy<=1.16.2,>=1.16.0
#   Using cached numpy-1.16.2-cp36-cp36m-manylinux1_x86_64.whl (17.3 MB)
# Processing /home/yuvraj/.cache/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787/dill-0.3.1.1-py3-none-any.whl
# Collecting sklearn-pandas<=1.7.0,>=1.4.0
#   Downloading sklearn_pandas-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting nimbusml>=1.5.0
#   Downloading nimbusml-1.7.0-cp36-none-manylinux1_x86_64.whl (116.2 MB)
#      |████████████████████████████████| 116.2 MB 4.1 MB/s
# Collecting lightgbm<=2.3.0,>=2.0.11
#   Using cached lightgbm-2.3.0-py2.py3-none-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-defaults~=1.2.0
#   Downloading azureml_defaults-1.2.0-py3-none-any.whl (3.0 kB)
# Collecting interpret-community==0.7.*
#   Downloading interpret_community-0.7.0-py3-none-any.whl (5.4 MB)
#      |████████████████████████████████| 5.4 MB 70 kB/s
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.0.4)
# Requirement already satisfied: traitlets>=4.3.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.3.3)
# Requirement already satisfied: future in /home/yuvraj/.local/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.18.2)
# Requirement already satisfied: jupyter-client in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.3.4)
# Requirement already satisfied: pyyaml in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.3.1)
# Requirement already satisfied: entrypoints in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.3)
# Requirement already satisfied: tenacity in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.1.0)
# Requirement already satisfied: nbconvert>=5.5 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (5.6.1)
# Requirement already satisfied: ansiwrap in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.4)
# Requirement already satisfied: tqdm>=4.32.2 in /home/yuvraj/.local/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.36.1)
# Requirement already satisfied: click in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (7.1.1)
# Requirement already satisfied: tornado>=4.2 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipykernel->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.0.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.0.5)
# Requirement already satisfied: pygments in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (2.6.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.8.0)
# Requirement already satisfied: backcall in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.1.0)
# Requirement already satisfied: pickleshare in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.16.0)
# Requirement already satisfied: setuptools>=18.5 in /home/yuvraj/.local/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (41.6.0)
# Requirement already satisfied: decorator in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.4.2)
# Requirement already satisfied: portalocker~=1.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from msal-extensions~=0.1.3->azure-identity>=1.2.0->azureml-dataprep[fuse]<1.4.0a,>=1.3.5->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied: pycparser in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.20)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.1->azureml-core~=1.2.0->azureml-sdk[automl,explain,notebooks]) (3.1.0)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.2.0->azureml-train~=1.2.0->azureml-sdk[automl,explain,notebooks]) (0.6.1)
# Requirement already satisfied: pycodestyle<2.6.0,>=2.5.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.2.0->azureml-train~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.5.0)
# Requirement already satisfied: pyflakes<2.2.0,>=2.1.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from flake8<=3.7.9,>=3.1.0; python_version >= "3.6"->azureml-train-core~=1.2.0->azureml-train~=1.2.0->azureml-sdk[automl,explain,notebooks]) (2.1.1)
# Requirement already satisfied: protobuf in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from onnx>=1.5.0->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (3.11.3)
# Collecting typing-extensions>=3.6.2.1
#   Downloading typing_extensions-3.7.4.1-py3-none-any.whl (20 kB)
# Collecting Cython>=0.29
#   Downloading Cython-0.29.16-cp36-cp36m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 3.2 MB/s
# Collecting JsonSir>=0.0.2
#   Downloading JsonSir-0.0.2.tar.gz (2.2 kB)
# Collecting python-easyconfig>=0.1.0
#   Downloading Python_EasyConfig-0.1.7-py2.py3-none-any.whl (5.4 kB)
# Collecting JsonForm>=0.0.2
#   Downloading JsonForm-0.0.2.tar.gz (2.4 kB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-1.10.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 3.6 MB/s
# Collecting keras2onnx
#   Downloading keras2onnx-1.6.0-py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 4.8 MB/s
# Collecting gunicorn==19.9.0
#   Using cached gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting configparser==3.7.4
#   Using cached configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Using cached Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting werkzeug==0.16.1
#   Using cached Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Processing /home/yuvraj/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee/json_logging_py-0.2-py3-none-any.whl
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Using cached azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting interpret-core[required]==0.1.20
#   Downloading interpret_core-0.1.20-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 4.6 MB/s
# Collecting shap<=0.34.0,>=0.20.0
#   Downloading shap-0.34.0.tar.gz (264 kB)
#      |████████████████████████████████| 264 kB 5.2 MB/s
# Collecting packaging
#   Downloading packaging-20.3-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: notebook>=4.4.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (6.0.3)
# Requirement already satisfied: jupyter-core in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.2.0)
# Requirement already satisfied: ipython-genutils in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from jupyter-client->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (19.0.0)
# Requirement already satisfied: testpath in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.4.4)
# Requirement already satisfied: jinja2>=2.4 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (2.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.4)
# Requirement already satisfied: bleach in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.1.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.4.2)
# Requirement already satisfied: defusedxml in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.6.0)
# Requirement already satisfied: textwrap3>=0.9.2 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from ansiwrap->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.9.2)
# Requirement already satisfied: wcwidth in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.1.9)
# Requirement already satisfied: ptyprocess>=0.5 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.6.0)
# Requirement already satisfied: parso>=0.5.2 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from jedi>=0.10->ipython->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.6.2)
# Collecting boto3
#   Downloading boto3-1.12.31-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 21.5 MB/s
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-1.26.0-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.4 MB/s
# Collecting fire
#   Downloading fire-0.3.0.tar.gz (81 kB)
#      |████████████████████████████████| 81 kB 5.1 MB/s
# Requirement already satisfied: itsdangerous>=0.24 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from flask==1.0.3->azureml-defaults~=1.2.0->azureml-train-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.1.0)
# Processing /home/yuvraj/.cache/pip/wheels/d1/6a/e7/529dc54d76ecede4346164a09ae3168df358945612710f5203/liac_arff-2.4.0-cp36-none-any.whl
# Requirement already satisfied: joblib>=0.11; extra == "required" in /home/yuvraj/.local/lib/python3.6/site-packages (from interpret-core[required]==0.1.20->interpret-community==0.7.*->azureml-interpret~=1.2.0->azureml-explain-model~=1.2.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (0.14.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/yuvraj/.local/lib/python3.6/site-packages (from packaging->interpret-community==0.7.*->azureml-interpret~=1.2.0->azureml-explain-model~=1.2.0; extra == "explain"->azureml-sdk[automl,explain,notebooks]) (2.4.2)
# Requirement already satisfied: Send2Trash in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.5.0)
# Requirement already satisfied: prometheus-client in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.7.1)
# Requirement already satisfied: terminado>=0.8.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.8.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.6.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from jinja2>=2.4->nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (1.1.1)
# Requirement already satisfied: webencodings in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from bleach->nbconvert>=5.5->papermill<2->azureml-contrib-notebook~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (0.5.1)
# Requirement already satisfied: botocore<1.16.0,>=1.15.31 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.15.31)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Using cached s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: google-resumable-media<0.6dev,>=0.5.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.5.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.2.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.3.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from google-cloud-storage->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.12.0)
# Processing /home/yuvraj/.cache/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6/termcolor-1.1.0-cp36-none-any.whl
# Requirement already satisfied: zipp>=0.5 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets~=1.2.0; extra == "notebooks"->azureml-sdk[automl,explain,notebooks]) (3.1.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.31->boto3->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.15.2)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.16.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.16.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (0.2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /home/yuvraj/anaconda3/envs/AzureDS/lib/python3.6/site-packages (from google-api-core<2.0.0dev,>=1.16.0->google-cloud-core<2.0dev,>=1.2.0->google-cloud-storage->smart-open>=1.8.1->gensim->azureml-automl-runtime~=1.2.0->azureml-train-automl~=1.2.0; extra == "automl"->azureml-sdk[automl,explain,notebooks]) (1.51.0)
# Building wheels for collected packages: py-cpuinfo, psutil, JsonSir, JsonForm, smart-open, shap, fire
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-py3-none-any.whl size=18682 sha256=bec0cfaaed6448dc08d4e49ce0d575965a12ed043165ac8256287bb3eae7ddfd
#   Stored in directory: /home/yuvraj/.cache/pip/wheels/e6/54/db/65176a1697a583d8ec5f90510f6faab11cda739d0e4f0ba2ea
#   Building wheel for psutil (setup.py) ... done
#   Created wheel for psutil: filename=psutil-5.7.0-cp36-cp36m-linux_x86_64.whl size=272811 sha256=74ffcd54103a82848263ab866dc53576d803800907f6561620881e3386693640
#   Stored in directory: /home/yuvraj/.cache/pip/wheels/a1/d9/f2/b5620c01e9b3e858c6877b1045fda5b115cf7df6490f883382
#   Building wheel for JsonSir (setup.py) ... done
#   Created wheel for JsonSir: filename=JsonSir-0.0.2-py3-none-any.whl size=4773 sha256=5a2725e43203130b4c2f362fd9d8d9f1aa59b27d4f8bae9e525f2e7064bb2802
#   Stored in directory: /home/yuvraj/.cache/pip/wheels/05/42/c2/d3cd8ea9f896260294ea5fbeb985905e81654b670d7753a419
#   Building wheel for JsonForm (setup.py) ... done
#   Created wheel for JsonForm: filename=JsonForm-0.0.2-py3-none-any.whl size=3324 sha256=56b67b6f5a1635c9a0dbe85f798e86c5d4fa62a1d569910141062bac24ca2c16
#   Stored in directory: /home/yuvraj/.cache/pip/wheels/15/f9/2d/61747ec74e70a079a428c54fc1167b03a4198a2e2ac4be5f07
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-1.10.0-py3-none-any.whl size=90631 sha256=892110110516c5e2cdbb76a48d6841d964f4d12b8bfed33fdd63c0823106dec9
#   Stored in directory: /home/yuvraj/.cache/pip/wheels/a1/f3/8a/c46924c44ee290a85840f98cab840a65669cd377175eaf6850
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.34.0-cp36-cp36m-linux_x86_64.whl size=387088 sha256=152406ed32e46b947ab92832e5d5e6d7c36a0cb8e332631d6e0f1bd06bf55fea
#   Stored in directory: /home/yuvraj/.cache/pip/wheels/88/56/c6/630b200696678c506f3057a1e7573c086e50d59fdcffcbfd04
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.3.0-py2.py3-none-any.whl size=111107 sha256=59e03e5e2f0272d07f81159c501eeb4b710bf212fdb919b2a80e5567e1371c94
#   Stored in directory: /home/yuvraj/.cache/pip/wheels/4c/6b/7a/70c9e258ec08f7516589543adbd961d3c74c41ccd861e0a708
# Successfully built py-cpuinfo psutil JsonSir JsonForm smart-open shap fire
# ERROR: ngboost 0.1.3 has requirement numpy>=1.17.2, but you'll have numpy 1.16.2 which is incompatible.
# ERROR: ngboost 0.1.3 has requirement scikit-learn>=0.21.3, but you'll have scikit-learn 0.20.3 which is incompatible.
# ERROR: ngboost 0.1.3 has requirement scipy>=1.3.1, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: autograd-gamma 0.4.1 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: kedro 0.15.8 has requirement pandas<1.0,>=0.24.0, but you'll have pandas 0.23.4 which is incompatible.
# Installing collected packages: numpy, scipy, pandas, typing-extensions, onnx, Cython, scikit-learn, pmdarima, py-cpuinfo, psutil, JsonSir, python-easyconfig, JsonForm, resource, wheel, s3transfer, boto3, google-cloud-storage, smart-open, gensim, onnxconverter-common, skl2onnx, termcolor, fire, keras2onnx, onnxmltools, dill, sklearn-pandas, nimbusml, lightgbm, azureml-automl-runtime, gunicorn, configparser, werkzeug, flask, json-logging-py, liac-arff, azureml-model-management-sdk, azureml-defaults, interpret-core, shap, packaging, interpret-community, azureml-interpret, azureml-explain-model, azureml-train-automl-runtime, azureml-train-automl
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.17.3
#     Uninstalling numpy-1.17.3:
#       Successfully uninstalled numpy-1.17.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.3.1
#     Uninstalling scipy-1.3.1:
#       Successfully uninstalled scipy-1.3.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.25.2
#     Uninstalling pandas-0.25.2:
#       Successfully uninstalled pandas-0.25.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.21.3
#     Uninstalling scikit-learn-0.21.3:
#       Successfully uninstalled scikit-learn-0.21.3
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.32.2
#     Uninstalling wheel-0.32.2:
#       Successfully uninstalled wheel-0.32.2
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 1.0.0
#     Uninstalling Werkzeug-1.0.0:
#       Successfully uninstalled Werkzeug-1.0.0
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.1
#     Uninstalling Flask-1.1.1:
#       Successfully uninstalled Flask-1.1.1
# Successfully installed Cython-0.29.16 JsonForm-0.0.2 JsonSir-0.0.2 azureml-automl-runtime-1.2.0 azureml-defaults-1.2.0 azureml-explain-model-1.2.0 azureml-interpret-1.2.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-train-automl-1.2.0 azureml-train-automl-runtime-1.2.0 boto3-1.12.31 configparser-3.7.4 dill-0.3.1.1 fire-0.3.0 flask-1.0.3 gensim-3.8.1 google-cloud-storage-1.26.0 gunicorn-19.9.0 interpret-community-0.7.0 interpret-core-0.1.20 json-logging-py-0.2 keras2onnx-1.6.0 liac-arff-2.4.0 lightgbm-2.3.0 nimbusml-1.7.0 numpy-1.16.2 onnx-1.6.0 onnxconverter-common-1.6.0 onnxmltools-1.4.1 packaging-20.3 pandas-0.23.4 pmdarima-1.1.1 psutil-5.7.0 py-cpuinfo-5.0.0 python-easyconfig-0.1.7 resource-0.2.1 s3transfer-0.3.3 scikit-learn-0.20.3 scipy-1.1.0 shap-0.34.0 skl2onnx-1.4.9 sklearn-pandas-1.7.0 smart-open-1.10.0 termcolor-1.1.0 typing-extensions-3.7.4.1 werkzeug-0.16.1 wheel-0.30.0

# %% [markdown]
# # 2. Creating a Workspace
# You can create a workspace in any of the following ways:
#
# * In the Microsoft Azure portal, create a new Machine Learning resource, specifying the subscription, resource group, workspace name, and workspace edition.
# * Use the Azure Machine Learning Python SDK to run code that creates a workspace. For example:
#
# ```python
# from azureml.core import Workspace
#
# ws = Workspace.create(name='aml-workspace',
#                   subscription_id='123456-abc-123...',
#                   resource_group='aml-resources',
#                   create_resource_group=True,
#                   location='eastus',
#                   sku='enterprise'
#                  )
# ```

# %%
from azureml.core import Workspace
from azureml.exceptions import WorkspaceException

# Create Azure Workspacefor the given subscription ID
try:
    ws = Workspace.create(name='azml-workspace', 
                          subscription_id=conf_catalog['azure_ml']['subscription_id'],
                          resource_group='aml-resources',
                          create_resource_group=True,
                          location='eastus',
                          sku='enterprise'
                         )
    ws.write_config(file_name="ws_config.json")
except WorkspaceException :
    print('Workspace Already Exists, hence not created.')
    print('Loading Worksapce from config')

    # Load Worskapce from config
    ws = Workspace.from_config()
    
    # Alternative , load from azure ml
    '''
    ws = Workspace.get(name="azml-workspace",
                       subscription_id=conf_catalog['azure_ml']['subscription_id'],
                       resource_group='aml-resources')
    '''
# Out:
# Workspace Already Exists, hence not created.
# Loading Worksapce from config
# 2020-03-28 20:59:53,611 - azureml.core.workspace - INFO - Found the config file in: /home/yuvraj/projects/AzureAworkspace/azureds/.azureml/config.json
